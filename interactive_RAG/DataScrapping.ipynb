# %% [markdown]
# # 네이버 뉴스 크롤링 - Graph DB 데이터 수집
#
# 네이버 뉴스에서 분야별 헤드라인 기사 수집
#
# - **정치**: https://news.naver.com/section/100
# - **경제**: https://news.naver.com/section/101
# - **사회**: https://news.naver.com/section/102
# - **생활/문화**: https://news.naver.com/section/103
# - **IT/과학**: https://news.naver.com/section/105
# - **세계**: https://news.naver.com/section/104
#
# ## 수집 항목 (Articles.xlsx)
# - article_id: 기사 고유 ID
# - title: 기사 제목
# - content: 기사 본문
# - url: 기사 URL
# - published_date: 발행일
# - source: 언론사
# - author: 기자명
# - category: 카테고리

# %% [markdown]
# ## 1. 필요한 패키지 설치 및 임포트

# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
from webdriver_manager.chrome import ChromeDriverManager
from selenium.webdriver.chrome.service import Service
import pandas as pd
import time
from datetime import datetime
import re

# %% [markdown]
# ## 2. 카테고리 설정 및 Selenium 초기화

# %%
categories = {
    '정치': 'https://news.naver.com/section/100',
    '경제': 'https://news.naver.com/section/101',
    '사회': 'https://news.naver.com/section/102',
    '생활/문화': 'https://news.naver.com/section/103',
    'IT/과학': 'https://news.naver.com/section/105',
    '세계': 'https://news.naver.com/section/104'
}

NUM_ARTICLES_PER_CATEGORY = 10

# %%
service = Service(ChromeDriverManager().install())
options = webdriver.ChromeOptions()
options.add_argument('--no-sandbox')
options.add_argument('--disable-dev-shm-usage')

driver = webdriver.Chrome(service=service, options=options)

# %% [markdown]
# ## 3. 기사 수집 함수 정의

# %%
def get_article_links(driver, category_url, num_articles):
    driver.get(category_url)
    time.sleep(3)

    article_links = []

    try:
        selectors = [
            'a.sa_text_lede',
            'a.sa_text_strong',
            '.sa_text a',
            '.cluster_text_headline a',
            '.cluster_text_lede a'
        ]

        for selector in selectors:
            elements = driver.find_elements(By.CSS_SELECTOR, selector)
            for element in elements:
                url = element.get_attribute('href')
                if (url and 'news.naver.com' in url and '/article/' in url
                    and '/comment/' not in url  # 댓글 페이지만 제외
                    and url not in article_links):
                    article_links.append(url)
                    if len(article_links) >= num_articles:
                        break
            if len(article_links) >= num_articles:
                break

        print(f"✓ {len(article_links)}개의 기사 링크 수집 완료")

    except Exception as e:
        print(f"✗ 기사 링크 수집 실패: {e}")

    return article_links[:num_articles]

# %%
def parse_article_detail(driver, article_url, category):
    driver.get(article_url)
    time.sleep(1.5)

    article_data = {
        'article_id': '',
        'title': '',
        'content': '',
        'url': article_url,
        'published_date': '',
        'source': '',
        'author': '',
        'category': category
    }

    try:
        # 기사 ID 생성 (URL에서 추출)
        match = re.search(r'article/(\d+)/(\d+)', article_url)
        if match:
            article_data['article_id'] = f"ART_{match.group(1)}_{match.group(2)}"
        else:
            article_data['article_id'] = f"ART_{datetime.now().strftime('%Y%m%d%H%M%S')}"

        # 제목
        title_selectors = [
            '#title_area span',
            '#ct .media_end_head_headline',
            '.media_end_head_headline',
            'h2#title_area',
            '.news_end_title'
        ]

        for selector in title_selectors:
            try:
                title_element = driver.find_element(By.CSS_SELECTOR, selector)
                if title_element.text.strip():
                    article_data['title'] = title_element.text.strip()
                    break
            except:
                continue

        # 본문
        content_selectors = [
            '#dic_area',
            'article#dic_area',
            '.go_trans._article_content',
            '._article_body_contents'
        ]

        for selector in content_selectors:
            try:
                content_element = driver.find_element(By.CSS_SELECTOR, selector)
                if content_element.text.strip():
                    article_data['content'] = content_element.text.strip()
                    break
            except:
                continue

        # 언론사
        try:
            source_element = driver.find_element(By.CSS_SELECTOR, 'a.media_end_head_top_logo img')
            article_data['source'] = source_element.get_attribute('alt')
        except:
            try:
                source_element = driver.find_element(By.CSS_SELECTOR, '.media_end_head_top_logo_text')
                article_data['source'] = source_element.text.strip()
            except:
                pass

        # 발행일
        try:
            date_element = driver.find_element(By.CSS_SELECTOR, 'span.media_end_head_info_datestamp_time, span[data-date-time]')
            date_text = date_element.get_attribute('data-date-time') or date_element.text
            article_data['published_date'] = date_text.strip()
        except:
            article_data['published_date'] = datetime.now().strftime('%Y-%m-%d %H:%M')

        # 기자명
        try:
            author_element = driver.find_element(By.CSS_SELECTOR, 'em.media_end_head_journalist_name, span.byline_s')
            article_data['author'] = author_element.text.strip()
        except:
            pass

    except Exception as e:
        print(f"  ✗ 파싱 오류: {e}")

    return article_data

# %% [markdown]
# ## 4. 전체 카테고리 크롤링 실행

# %%
# 전체 기사 데이터를 저장할 리스트
all_articles = []

# 카테고리별 크롤링
for category_name, category_url in categories.items():
    print(f"\n{'='*60}")
    print(f"[{category_name}] 카테고리 수집 시작...")
    print(f"{'='*60}")

    # 1단계: 기사 링크 수집
    article_links = get_article_links(driver, category_url, NUM_ARTICLES_PER_CATEGORY)

    # 2단계: 각 기사 상세 정보 수집
    for idx, article_url in enumerate(article_links, 1):
        print(f"  [{idx}/{len(article_links)}] {article_url}")
        article_data = parse_article_detail(driver, article_url, category_name)

        if article_data['title']:  # 제목이 있는 경우만 추가
            all_articles.append(article_data)
            print(f"  ✓ 수집 완료: {article_data['title'][:50]}...")
        else:
            print(f"  ✗ 수집 실패 - 제목을 찾을 수 없습니다.")

        time.sleep(0.5)
# Out:
# ============================================================
# [정치] 카테고리 수집 시작...
# ============================================================
# ✓ 10개의 기사 링크 수집 완료
#   [1/10] https://n.news.naver.com/mnews/article/018/0006168585
#   ✓ 수집 완료: 北, 사업 성공한 부부 ‘공개 처형’…“태도 오만해”...
#   [2/10] https://n.news.naver.com/mnews/article/421/0008616962
#   ✓ 수집 완료: 李대통령, 남아공서 프랑스·독일과 정상회담…"국제정세 변화 대응"...
#   [3/10] https://n.news.naver.com/mnews/article/366/0001124550
#   ✓ 수집 완료: ‘마이웨이’ 법사위에 뿔난 與 지도부… “대통령 외교 성과 또 빛바랠라’”...
#   [4/10] https://n.news.naver.com/mnews/article/052/0002276132
#   ✓ 수집 완료: 이 대통령 "남북 대결 끝내고 평화 공존의 시대로...단계적 비핵화 추진"...
#   [5/10] https://n.news.naver.com/mnews/article/449/0000327216
#   ✓ 수집 완료: 이 대통령 지지율 60%…민주 43%·국힘 24%...
#   [6/10] https://n.news.naver.com/mnews/article/277/0005682723
#   ✓ 수집 완료: 송언석 "정부혁신 TF, 야만적 공무원 줄세우기...김문기법 추진"...
# ============================================================
# [IT/과학] 카테고리 수집 시작...
# ============================================================
# ✓ 10개의 기사 링크 수집 완료
#   [1/10] https://n.news.naver.com/mnews/article/009/0005593962
#   ✓ 수집 완료: 네오위즈 ‘P의 거짓: 서곡’, 골든 조이스틱 어워드 2025 수상...
#   [2/10] https://n.news.naver.com/mnews/article/001/0015755498
#   ✓ 수집 완료: KISA 버그바운티, 제보량·위험도 모두 '역대 최고'...
#   [3/10] https://n.news.naver.com/mnews/article/421/0008617968
#   ✓ 수집 완료: 국민 데이터 대규모 처리기관 94% '안전조치 의무이행 미흡'...
#   [4/10] https://n.news.naver.com/mnews/article/052/0002276286
#   ✓ 수집 완료: 이노스페이스 첫 상업 발사 다음 달 17일로 연기...
#   [5/10] https://n.news.naver.com/mnews/article/243/0000088392
#   ✓ 수집 완료: "포토샵 필요 없다" 진화한 '나노 바나나 프로'…구글, AI 이미지 진짜·가짜 구분 기능...
#   [6/10] https://n.news.naver.com/mnews/article/056/0012071087
#   ✓ 수집 완료: 소송자료 18만 건 해킹…법무법인 ‘로고스’ 과징금...
#   [7/10] https://n.news.naver.com/mnews/article/277/0005682790
#   ✓ 수집 완료: 네오플 노사, 임금 400만원 인상 등 임단협 합의안 가결...
#   [8/10] https://n.news.naver.com/mnews/article/366/0001124857
#   ✓ 수집 완료: 텔레픽스, 위성·AI로 분석한 가자지구 피해 공개…1년 새 건물 42% 파괴...
#   [9/10] https://n.news.naver.com/mnews/article/138/0002210299
#   ✓ 수집 완료: [삼성리더십] "근본부터 AI 기업" 강조한 노태문, DX·MX 총괄…'따로 또 같이' A...
#   [10/10] https://n.news.naver.com/mnews/article/092/0002399399
#   ✓ 수집 완료: ETRI "AI로봇 '두뇌' 주권 프로젝트 정부에 제안 추진"...
#
# ============================================================
# [세계] 카테고리 수집 시작...
# ============================================================
# ✓ 10개의 기사 링크 수집 완료
#   [1/10] https://n.news.naver.com/mnews/article/016/0002561078
#   ✓ 수집 완료: 트럼프, ‘고물가 압박’ 속 브라질 농산물에 40% 추가관세 면제...
#   [2/10] https://n.news.naver.com/mnews/article/001/0015755507
#   ✓ 수집 완료: "AI 위험 바로미터는 오라클"…오라클 CDS 급등...
#   [3/10] https://n.news.naver.com/mnews/article/003/0013612549
#   ✓ 수집 완료: 대만 라이칭더, 日해산물 먹는 사진 공개…"다카이치 지지 의도"...
#   [4/10] https://n.news.naver.com/mnews/article/032/0003410297
#   ✓ 수집 완료: 중·러, 고위급 외교·군사 회담 열고 미사일 방어 논의...
#   [5/10] https://n.news.naver.com/mnews/article/081/0003593918
#   ✓ 수집 완료: “500엔 대신 ‘500원’ 한국 동전 내고 가” 일본서 피해 속출...
#   [6/10] https://n.news.naver.com/mnews/article/052/0002276167
#   ✓ 수집 완료: "한국, '핵무기 개발 안한다' 선제적 입장 필요"...
#   [7/10] https://n.news.naver.com/mnews/article/001/0015754888
#   ✓ 수집 완료: 러 우크라 동부 쿠피안스크 재점령…푸틴 지휘소 시찰...
#   [8/10] https://n.news.naver.com/mnews/article/015/0005214263
#   ✓ 수집 완료: 美 "우크라 종전안 우크라 측에도 설명…양측에 모두 유리"...
#   [9/10] https://n.news.naver.com/mnews/article/029/0002994898
#   ✓ 수집 완료: “핵무기도 방어”…중국, 138m 길이 ‘인공 부유섬’ 만든다...
#   [10/10] https://n.news.naver.com/mnews/article/215/0001231809
#   ✓ 수집 완료: "편하고 값도 싸다"…'먹는 비만약' 등장 예고...

# %% [markdown]
# ## 5. 수집 결과 확인

# %%
df_articles = pd.DataFrame(all_articles)

# %%
df_articles
# Out:
#             article_id                                              title  \
# 0   ART_018_0006168585                      北, 사업 성공한 부부 ‘공개 처형’…“태도 오만해”
# 1   ART_421_0008616962               李대통령, 남아공서 프랑스·독일과 정상회담…"국제정세 변화 대응"
# 2   ART_366_0001124550          ‘마이웨이’ 법사위에 뿔난 與 지도부… “대통령 외교 성과 또 빛바랠라’”
# 3   ART_052_0002276132          이 대통령 "남북 대결 끝내고 평화 공존의 시대로...단계적 비핵화 추진"
# 4   ART_449_0000327216                        이 대통령 지지율 60%…민주 43%·국힘 24%
# 5   ART_277_0005682723              송언석 "정부혁신 TF, 야만적 공무원 줄세우기...김문기법 추진"
# 6   ART_366_0001124755         李대통령, 이집트 정상회담 종료… “국제 평화 함께 기여… 방산 협력 확대”
# 7   ART_079_0004088251                  金여사, 이집트 영부인과 친교…"'K-할랄푸드' 대접하고파"
# 8   ART_015_0005214392                 李대통령 "민주주의의 우뚝 선 봉우리"…김영삼 전 대통령 추모
# 9   ART_016_0002561105        ‘공천 혁명’이냐 ‘연임 노림수’냐…정청래 ‘1인1표제’ 실현 임박[이런정치]
# 10  ART_016_0002560986                   셀트리온, 2년 연속 KCGS ESG 평가 ‘A등급’ 획득
# 11  ART_018_0006169339                          “연말정산 자료, 한번에 편리하게 받아보세요”
# 12  ART_421_0008617776                  소공연 "경영안정바우처 예산삭감 주장 반대…폐업선고와 같아"
# 13  ART_001_0015755665                 로봇 인증 간소화·AI 특별연장근로…경총, 규제혁신 과제 건의
# 14  ART_032_0003410262            HD현대아너상 대상에 정덕환씨…“장애인 자립과 사회 참여 확장에 기여”
# 15  ART_018_0006169058                        코트라, 한-UAE AI·에너지 경협 플라자 개최
# 16  ART_009_0005593827     “포람페, 그동안 고생했다”…차원이 다른 한국차, 제네시스 고성능 나왔다 [카슐랭]
# 17  ART_001_0015754623                    쿠팡서 고객 4천500여명 정보 노출…정부에 신고(종합)
# 18  ART_277_0005682432  BNK금융그룹, 부산서 스타트업·핀테크 회원사 초청 ‘Storage B 멤버십 데이...
# 19  ART_215_0001231786                     유안타증권, 금감원 'XBRL 재무공시 우수법인' 선정
# 20  ART_002_0002415473        '20년' 만에 대구지하철 21일 시한부 파업…시 “비상수송 체계 즉시 가동”
# 21  ART_025_0003484279                                  포스코서 가스사고…3명 의식불명
# 22  ART_023_0003942403              ‘고수익’ 미끼... 국내외서 투자리딩방 사기친 일당 118명 검거
# 23  ART_005_0001815901                “왜 휴대폰 안 바꿔줘” 집에 불 지른 여중생…17명 병원 이송
# 24  ART_366_0001124872                 해병특검, ‘채 상병 수사외압’ 윤석열·이종섭 등 12명 기소
# 25  ART_018_0006169147                    '항소포기 관여' 박철우 중앙지검장 "구성원 반발 이해"
# 26  ART_015_0005214425                   20년 만에 진실 밝혀졌다…'신정동 연쇄살인' 범인 정체는
# 27  ART_003_0013614082                [광주소식]광산구 '대한민국 주거복지문화대상' 종합대상 수상 등
# 28  ART_028_0002777545                   7차례 ‘학교에 폭발물 설치’ 협박 글, 인천 고교생 구속
# 29  ART_021_0002751771                        성주 ‘사드 반대 마지막 시설물’ 오늘 강제 철거
# 30  ART_214_0001463027                   [날씨] 주말까지 큰 추위 없어‥영동 건조·강풍, 산불조심
# 31  ART_421_0008617470                "북미 성공 이어간다"…하이브리드 탑재 '신형 텔루라이드' 출격
# 32  ART_003_0013614325          이슬람 미술 정수 한 자리에…국중박, 첫 '이슬람실' 신설 [뉴시스Pic]
# 33  ART_015_0005214379                  브랜드 역사상 가장 스포티한 차 온다…'마이바흐 SL' 출시
# 34  ART_081_0003594175       오스트리아 경매 시장에 나온 국내 불교유산…조계종이 낙찰, 160년만에 돌아왔다
# 35  ART_016_0002560996          현대차, ‘LA 오토쇼’서 콤팩트 오프로드 콘셉트카 ‘크레이터’ 최초 공개
# 36  ART_119_0003028074               혼다 'CR-V 하이브리드' 보러 가자…스타필드 하남서 팝업 전시
# 37  ART_296_0000094908           “추우면 더 생각나”…떡볶이 vs 튀김, 살이 덜 찌려면 어떻게 먹을까?
# 38  ART_296_0000094907               “변기보다 3000배 더 더럽다”…전자담배에 득실대는 세균들 보니
# 39  ART_029_0002994900                여친이 돈 빌려달라는데…얼마까지 가능? 男女 인식 차이 ‘뚜렷’
# 40  ART_009_0005593962              네오위즈 ‘P의 거짓: 서곡’, 골든 조이스틱 어워드 2025 수상
# 41  ART_001_0015755498                     KISA 버그바운티, 제보량·위험도 모두 '역대 최고'
# 42  ART_421_0008617968                 국민 데이터 대규모 처리기관 94% '안전조치 의무이행 미흡'
# 43  ART_052_0002276286                        이노스페이스 첫 상업 발사 다음 달 17일로 연기
# 44  ART_243_0000088392  "포토샵 필요 없다" 진화한 '나노 바나나 프로'…구글, AI 이미지 진짜·가짜 구...
# 45  ART_056_0012071087                       소송자료 18만 건 해킹…법무법인 ‘로고스’ 과징금
# 46  ART_277_0005682790                   네오플 노사, 임금 400만원 인상 등 임단협 합의안 가결
# 47  ART_366_0001124857         텔레픽스, 위성·AI로 분석한 가자지구 피해 공개…1년 새 건물 42% 파괴
# 48  ART_138_0002210299  [삼성리더십] "근본부터 AI 기업" 강조한 노태문, DX·MX 총괄…'따로 또 같...
# 49  ART_092_0002399399                 ETRI "AI로봇 '두뇌' 주권 프로젝트 정부에 제안 추진"
# 50  ART_016_0002561078               트럼프, ‘고물가 압박’ 속 브라질 농산물에 40% 추가관세 면제
# 51  ART_001_0015755507                       "AI 위험 바로미터는 오라클"…오라클 CDS 급등
# 52  ART_003_0013612549                대만 라이칭더, 日해산물 먹는 사진 공개…"다카이치 지지 의도"
# 53  ART_032_0003410297                     중·러, 고위급 외교·군사 회담 열고 미사일 방어 논의
# 54  ART_081_0003593918              “500엔 대신 ‘500원’ 한국 동전 내고 가” 일본서 피해 속출
# 55  ART_052_0002276167                       "한국, '핵무기 개발 안한다' 선제적 입장 필요"
# 56  ART_001_0015754888                       러 우크라 동부 쿠피안스크 재점령…푸틴 지휘소 시찰
# 57  ART_015_0005214263                   美 "우크라 종전안 우크라 측에도 설명…양측에 모두 유리"
# 58  ART_029_0002994898                 “핵무기도 방어”…중국, 138m 길이 ‘인공 부유섬’ 만든다
# 59  ART_215_0001231809                         "편하고 값도 싸다"…'먹는 비만약' 등장 예고
#
#                                               content  \
# 0   북한 개인 사업 운영 50대 부부,\n“오만해졌다” 야외 공간서 처형\n당국 “대중...
# 1   G20 계기 유럽 핵심 강국 佛·獨 양자회담 성사\n"MIKTA 회동서 다자주의·국...
# 2   김병기 “협의했어야… 뒷감당은 법사위가”\n\n더불어민주당 지도부와 국회 법제사법위...
# 3   이집트를 공식 방문 중인 이재명 대통령은 남북 적대와 대결의 시대를 끝내고, 평화 ...
# 4   이집트를 공식 방문 중인 이재명 대통령과 김혜경 여사가 20일(현지 시간) 카이로 ...
# 5   "공무원 성실 행정 면책 입법 추진"\n송언석 국민의힘 원내대표는 21일 공무원을 ...
# 6   이집트를 공식 방문 중인 이재명 대통령은 20일(현지시각) 압델 파타 알시시 대통령...
# 7   핵심요약\n인티사르 여사 "예전처럼 알던 친구같다…교류 활발해지기를"\n이재명 대통...
# 8   사진=연합뉴스\n\n이재명 대통령은 김영삼 전 대통령 서거 10주기인 21일 김 전...
# 9   더불어민주당 당헌·당규 개정 의결 과정 착수\n정청래 “90% 당원 뜻은 거스를 수...
# 10  환경·사회·지배구조 전 분야 긍정 평가\n지속가능한 기업 경영 활동 인정받아\n\n...
# 11  국세청 ‘간소화자료 일괄제공 서비스’\n오는 30일까지 1차 신청 접수\n자료수집 ...
# 12  소공연 "전액 삭감은 폐업 선고 다름없어"\n소상공인연합회/뉴스1 DB\n\n\n(...
# 13  '피지컬 AI 시대' 팝콘 담는 로봇\n(고양=연합뉴스) 임병식 기자 = 5일 경기...
# 14  시상식은 다음달 9일 개최\n정덕환씨. HD현대 제공\n\n\nHD현대1%나눔재단은...
# 15  정상 순방으로 무르익은 협력 의지\nUAE 진출 더욱 탄력받을 듯\n[이데일리 김성...
# 16  제네시스 GV60 마그마 [사진출처=현대차]\n포르쉐, 람보르기니, 페라리와 경쟁할...
# 17  이름·이메일·전화번호·주소 등 주문 번호 노출\n\n\n쿠팡\n[연합뉴스 자료 사진...
# 18  혁신 공간 ‘스페이스 원지’서 네트워킹·협업 강화… 핀테크 산업 발전 기여\nBNK...
# 19  (왼쪽부터)양동빈 유안타증권 CFO, 이승우 금융감독원 부원장보가 시상식 후 기념사...
# 20  시민 불편 최소화 위해 비상교통상황실 구성\n\n대구교통공사 노조가 21일 시한부 ...
# 3      YTN                                 홍민기 기자       정치
# 4      채널A             윤승옥 기자 touch@ichannela.com       정치
# 5    아시아경제                                 최유리 기자       정치
# 6     조선비즈                                 이윤정 기자       정치
# 7     노컷뉴스                                 이준규 기자       정치
# 8     한국경제                                 박수림 기자       정치
# 9    헤럴드경제                                 양근혁 기자       정치
# 10   헤럴드경제                                 최은지 기자       경제
# 11    이데일리                                 강신우 기자       경제
# 12     뉴스1                                 장시온 기자       경제
# 13    연합뉴스                                 홍규빈 기자       경제
# 14    경향신문                                 김경학 기자       경제
# 15    이데일리                                 김성진 기자       경제
# 16    매일경제                                 최기성 기자       경제
# 17    연합뉴스                                 신선미 기자       경제
# 18   아시아경제     영남취재본부 조충현 기자 jchyoung@asiae.co.kr       경제
# 19  한국경제TV                                 김채영 기자       경제
# 20    프레시안                                 권용현 기자       사회
# 21    중앙일보                                 백경서 기자       사회
# 22    조선일보             대전=우정식 기자 jswoo@chosun.com       사회
# 23    국민일보                                 박민지 기자       사회
# 24    조선비즈                                 유병훈 기자       사회
# 25    이데일리                                 송승현 기자       사회
# 26    한국경제                                 박수빈 기자       사회
# 27     뉴시스                                 박기웅 기자       사회
# 28     한겨레                                 이준희 기자       사회
# 29    문화일보                                 박천학 기자       사회
# 30     MBC                                금채림 캐스터    생활/문화
# 31     뉴스1                                 박기범 기자    생활/문화
# 32     뉴시스                               박주성 외 2명    생활/문화
# 33    한국경제                                 차은지 기자    생활/문화
# 34    서울신문                                 윤수경 기자    생활/문화
# 35   헤럴드경제                                 서재근 기자    생활/문화
# 36    데일리안                                 편은지 기자    생활/문화
# 37   코메디닷컴                                 권나연 기자    생활/문화
# 38   코메디닷컴                                 정은지 기자    생활/문화
# 39  디지털타임스                                 김성준 기자    생활/문화
# 40    매일경제                                 김태성 기자    IT/과학
# 41    연합뉴스                                 박형빈 기자    IT/과학
# 42     뉴스1                                 이기림 기자    IT/과학
# 43     YTN                                 고한석 기자    IT/과학
# 44  이코노미스트                                 우승민 기자    IT/과학
# 45     KBS                                    KBS    IT/과학
# 46   아시아경제                                 노경조 기자    IT/과학
# 47    조선비즈                                 홍아름 기자    IT/과학
# 48  디지털데일리                                 옥송이 기자    IT/과학
# 49  지디넷코리아                                 박희범 기자    IT/과학
# 50   헤럴드경제                                 김영철 기자       세계
# 51    연합뉴스                                 황정우 기자       세계
# 52     뉴시스                                 문예성 기자       세계
# 53    경향신문  베이징 | 박은하 특파원 eunha999@kyunghyang.com       세계
# 54    서울신문                                 권윤희 기자       세계
# 55     YTN                                 신윤정 기자       세계
# 56    연합뉴스                                 최인영 기자       세계
# 57    한국경제                                 박수림 기자       세계
# 58  디지털타임스                                 김광태 기자       세계
# 59  한국경제TV              김현경 기자 khkkim@wowtv.co.kr       세계

# %% [markdown]
# ## 6. Excel 파일로 저장

# %%
output_filename = f"Articles_{datetime.now().strftime('%Y%m%d_%H%M%S')}.xlsx"
df_articles.to_excel(output_filename, index=False, engine='openpyxl')

# %%
driver.quit()
